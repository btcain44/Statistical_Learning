# %% [markdown]
# ### Assignment 3 - Brian Cain
#
# <b><u>Problem 1:</u></b>
#
# <b>Part A:</b>
#
# Something to be conscious of when conducting Part A, is determining if there are any features in the dataset for Model B (discriminant analysis), as a result of discriminant analysis not being compatible with categorical features. I was able to do some research at this link: https://search.r-project.org/CRAN/refmans/kernlab/html/spam.html, which contained details for this specific dataset and it indicates no variables are categorical, so we need not worry about this issue when deciding upon covariates. More evidence that there are no categorical variables is pictured below from the link.
#
# ![image.png](attachment:image.png)
