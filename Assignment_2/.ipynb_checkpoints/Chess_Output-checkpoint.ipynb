# %% [markdown]
# ### Problem 1:

# %% [markdown]
# <b>Part A:</b> Produce a pairwise scatteplot with USCF Regular Rating as the top row
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Above we can view the pariwise plot output, with USCF Regular Rating in the top row. As general observation, most of the variables have relatively positive correlations with eachother. This makes sense, because they are all metrics that rate a players chess skill level, so if one increases, it is only natural for another to increase as well, and vice versa.
#
# A more specific observation we can make is the positive correlation between Chess.com Blitz Rating and Bullet rating, we can see the plotted points are very tight together with a clear positive correlation. This makes sense as they are both fast version of chess. Whereas, if we look at the plot which plots USCF Regular Rating vs. Chess.com Blitz Rating or Chess.com Bullet rating, we can see there is still a positive correlation but the data points are slightly less tightly grouped together in a clean line. This gives us insight that the relationship between Blitz and Bullet chess ratings are more strongly correlated and indicative of performance between the ratings than is the relationship between USCF Regular rating and a fast chess rating.

# %% [markdown]
# <b>Part B:</b>
#
# Write a theoretical simple regression model:
# * $y_i = \beta_0 + \beta_1 \cdot x_i + \epsilon_i$ for $i=1,...,n$
# * $\beta_0 = $ not sure
# * $\beta_1 = $ average change in USCF Regular Rating for a unit change in Chess.com live standard rating
#
# Output when the model is fit:
# ![image.png](attachment:image.png)

# %% [markdown]
# In the output above, we can observe the OLS estimates for our defined coefficients:
# * $\hat{\beta_0} = 349.5847$
# * $\hat{\beta_1} = 0.8052$
#
# Computing the 95% Confidence Intervals:
# * For $\hat{\beta_0}$, 95% CI is [-39.765,738.934] rounded to three decimals
# * For $\hat{\beta_1}$, 95% CI is [0.558,1.052] rounded to three decimals
#
# Parameter Estimates Signficantly Different from 0:
# * At a 95% confidence level, $\hat{\beta_0}$ is not significantly different from 0. This is true because the 95% CI  [-39.765,738.934] contains 0, so there is a possibly the intercept is in fact 0.
# * At a 95% confidence level, $\hat{\beta_1}$ is significantly different from 0. We know this because the 95% CI [0.558,1.052] does not contain 0.

# %% [markdown]
# <b>Part C:</b> Model Diagnostic Plots
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <b>Residuals vs. Fitted:</b> On the right hand side of this plot, we can observe that the error terms are relatively spread out without structure, outside of observation 272 which is a potential outlier. This side of the plot would indicate we have homoskedacity. However, on the left-hand side of the plot, the residual for observation 339 is a major outlier and obstructs homoskedacity to an extent. This is a point we should investigate when we move to <b>Part D</b>.
#
# <b>Normal Q-Q:</b> The left-hand side tail appears to be heavy, specifically as a result of observation 138. However, for the most part this Normal Q-Q plot is encouraging that the data is normal, as the plotted standardized residuals follow the theoretical quantile line rather closely.
#
# <b>Scale-Location:</b> Much like the Residuals vs. Fitted plot, observation 339 hinders the plots ability to have a line stright across the horizontal axis, which typically indicates homoskedacity. As well, we can notice that observation 272 and a couple of points near 272 could be outliers as they are fairly far away from the fitted line in this plot. One encouraging observation is that most of the residuals do not follow a pattern, indicating homoskedacity.
#
# <b>Residuals vs. Leverage:</b> Again 339 appears as a probable outlier in the dataset, and in particular displays huge leverage in this dataset. 339 also displays a large Cook's distance value indicating it has a large influence on the fit of the linear model.

# %% [markdown]
# <b>Part D:</b> Remove outliers/high leverage points and redo Part B
#
# Before we jump into removing the observed outliers/high leverage points found in <b>Part C</b>, we can observe some additional deficiencies with the data by calling the summary function on our data.
#
# Chess.com Live Standard Rating Descriptive Statistics:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# USCF Regular Rating Descriptive Statistics:
# ![image.png](attachment:image.png)

# %% [markdown]
# Taking a look at a summary of the data we can observe the following issues:
# * Both features Chess.com Live Standard Rating and USCF Regular Rating have a minimum value of 0, however its given that the lowest possible rating is 100
# * Both features have a significant number of missing values. This is particularly concerning because the dataset as a whole only has 410 observations, and the USCF Regular Rating has 291 missing values, meaning our regression doesn't have nearly as much data to fit the relationship with
#
# Before removing outliers/high leverage points, lets address the data integrity issues found above:
# 1. <b>Minimum values of 0:</b> I will assume this is a data entry error and replace all ratings less than 0 to be replaced with a value of 100
# 2. <b>Missing Values:</b> R lm() automatically disregards missing values. Since 291/410 values are missing from the USCF Regular Rating feature, we don't really have a representative way of imputing values into each of those missing values and still preserve an accurate linear relationship between Live Standard Rating the Regular rating, therefore I will continue to just ignore missing values and exclude them from the regression.

# %% [markdown]
# Address Outliers/High Leverage Points:
#
# Leverage Values (Potential for $y_i$ to influence the final fit)
# * Observation 339 has a leverage value of .376 (3 decimals), the next closest leverage is .054
#
# Cooks Distance (Actual influence of $y_i$ on final fit)
# * Observation 339 has Cook's distance of 7.308, the next closest is .349
#
# ![image.png](attachment:image.png)
#
# Looking at observation 339, we can actually observe that this was previously one of the rows with a rating of 0, that we have assumed to be a data error and the value has been adjusted to 100. However, this point is still high in leverage, I re-fitted the model after adjusting the 0 rating to be 100 and the Cooks distance was 6.127 while the leverage was .345, so we can see that even with the data cleaning step, this point still has major leverage on the model and is therefore removed.</b>
#
# Additional Outliers:
# * We will also remove observation 272 as a result of appearing to be an outlier in both the Residuals vs. Fitted plot and Scale-Location plot

# %% [markdown]
# New Fitted Regression Information:
#
# Model Summary:
# ![image.png](attachment:image.png)
#
# 95% Confidence Intervals
# * $\hat{\beta_0}$ 95% CI [-539.550,179.960] (3 decimal place)
# * $\hat{\beta_1}$ 95% CI [0.921,1.373] (3 decimal place)
#
# Significantly Different from Zero:
# * $\hat{\beta_0}$ is still not significantly different from zero as zero is contained within the 95% CI
# * $\hat{\beta_1}$ is significantly different from zero as zero is not in the 95% CI

# %% [markdown]
# Diagnostic Plots:
# ![image.png](attachment:image.png)

# %% [markdown]
# After re-fitting the linear model, the diagnostic plots look significantly better than the first time around. Although there are still some points that could be outliers. On the Residuals vs. Fitted plot there is a much more even spread of points around the center line as a result of removing observations 339 and 272, making the residuals appear much more homoskedastic, which is a great sign. We can notice that points 280, and 278 might still appear to be outliers but are not quite as concerning as they are not too far from the rest of the residuals like 339 was previously.
#
# As well, in our Normal Q-Q plot, outside of observation 280, it appears we have a very normal distribution when the standardized residuals are plotted against the theoretical quantiles, the heavier left-hand tail from the first model appears to have dissapeared to an extent.
#
# For Scale-Location, we can see a much more uniform/random spread of square rooted residuals against the fitted values, unlike the plot for the first model. This is more indicative again of homoskedacity showing equal variance across fitted values. We can still notice observation 280 and 278 showing up again as potential new outliers, but not nearly as influential as the previous outliers that were removed.
#
# Finally, we can explore Leverage and Cook's distance. The red line on this plot looks amazing in comparison to the original fitted model. It does not appear that any point has massive leverage on the model fit like point 339 did. However, we do still have some concern about points 280, 293, and 92 and their influence on the fit. When we calculate the Cook's distance, point 280 has cooks distance of 0.326, 293 has 0.126, and 92 has 0.095. So points 280 and 293 do still have larger actual influence on the fit, and if asked to continue removing outliers after this fit it is likely I would remove this two after further exploration of those points to see if they should be kept.
#
# <b>Part E:</b> A few observations can be made from the different parameter estimations in Part B and D. They are as follows:
# * Part D parameter estimates have narrower Confidence Intervals for $\hat{\beta_0}$ and $\hat{\beta_1}$
# * Part B model with parameters had an Adjusted R-Squared of 0.3428, while Part D had 0.5716, indicating the parameter estimates for the model perfom better at explaining variation in the data

# %% [markdown]
# first b0 778.699
# first b1 .494
#
# second b0 719.51
# second b1 .452

# %% [markdown]
# <b>Part F:</b>
#
# Average 1600 rated Player on Chess.com rate in UCSF Rating System:
# ![image.png](attachment:image.png)

# %% [markdown]
# Predicted UCSF Rating:
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Part G:</b> To assess which rating systems grant the best predictions for USCF Regular Ratings, we want to judge different simple regression models goodness of fit. We can judge performance on having a smaller RSS and higher $r^2$ value.
